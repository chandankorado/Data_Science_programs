# %%
# PANDASSS

import pandas as pd
df = pd.read_csv("bollywood.csv")
df
# Out:
#      SlNo Release Date                    MovieName ReleaseTime      Genre  \
# 0       1    18-Apr-14                     2 States          LW    Romance
# 1       2     4-Jan-13                 Table No. 21           N  Thriller
# 2       3    18-Jul-14           Amit Sahni Ki List           N     Comedy
# 3       4     4-Jan-13             Rajdhani Express           N     Drama
# 4       5     4-Jul-14                 Bobby Jasoos           N     Comedy
# ..    ...          ...                          ...         ...        ...
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N     Comedy
# 145   146    13-Mar-15                         NH10           N   Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N     Comedy
# 147   148    20-Mar-15                     Hunterrr           N     Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS     Action
#
# ...

# %%
df.to_string()
# Out:
# '     SlNo Release Date                             MovieName ReleaseTime      Genre  Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes\n0       1    18-Apr-14                              2 States          LW    Romance      36               104.00       8576361         26622             2527\n1       2     4-Jan-13                          Table No. 21           N  Thriller       10                12.00       1087320          1129              137\n2       3    18-Jul-14                    Amit Sahni Ki List           N     Comedy      10                 4.00        572336           586               54\n3       4     4-Jan-13                      Rajdhani Express           N     Drama        7                 0.35         42626            86               19\n4       5     4-Jul-14                          Bobby Jasoos           N     Comedy      18                10.80       3113427          4512             1224\n5       6    30-May-14                     
# ...

# %%
pd.Option.display.max-rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 pd.Option.display.max-rows
#
# File C:\Python310\lib\site-packages\pandas\__init__.py:261, in __getattr__(name)
#     257     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     259     return _SparseArray
# --> 261 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'Option'

# %%
df.head(10)
# Out:
#    SlNo Release Date                   MovieName ReleaseTime      Genre  \
# 0     1    18-Apr-14                    2 States          LW    Romance
# 1     2     4-Jan-13                Table No. 21           N  Thriller
# 2     3    18-Jul-14          Amit Sahni Ki List           N     Comedy
# 3     4     4-Jan-13            Rajdhani Express           N     Drama
# 4     5     4-Jul-14                Bobby Jasoos           N     Comedy
# 5     6    30-May-14                  Citylights          HS     Drama
# 6     7    19-Sep-14               Daawat-E-Ishq           N     Comedy
# 7     8    11-Jan-13  Matru Ki Bijlee Ka Mandola           N     Comedy
# 8     9    10-Jan-14                Dedh Ishqiya          LW     Comedy
# 9    10    11-Jan-13                   Gangoobai           N     Drama
#
#    Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 0      36               104.00       8576361         26622             2527
# ...

# %%
df.tail(10)
# Out:
#      SlNo Release Date                    MovieName ReleaseTime     Genre  \
# 139   140    30-Jan-15                   Hawaizaada           N    Drama
# 140   141    30-Jan-15                  Khamoshiyan           N  Thriller
# 141   142     6-Feb-15                    Shamitabh           N    Drama
# 142   143    13-Feb-15                          Roy          FS   Romance
# 143   144    20-Feb-15                     Badlapur          FS    Action
# 144   145    27-Feb-15           Dum Laga Ke Haisha           N    Comedy
# 145   146    13-Mar-15                         NH10           N  Thriller
# 146   147    20-Mar-15  Dilliwali Zaalim Girlfriend           N    Comedy
# 147   148    20-Mar-15                     Hunterrr           N    Comedy
# 148   149    23-May-14                Kochadaiiyaan          HS    Action
#
#      Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# 139      25                30.25       2368404          8619              539
# ...

# %%
x = df.head(50)
x.tail(10)
# Out:
#     SlNo Release Date                         MovieName ReleaseTime     Genre  \
# 40    41     8-Mar-13  Saheb, Biwi Aur Gangster Returns          FS    Drama
# 41    42    24-Jan-14                            Jai Ho           N    Action
# 42    43    19-Sep-14                        Khoobsurat           N   Romance
# 43    44    25-Jul-14                              Kick           N    Action
# 44    45    15-Mar-13                                3G           N  Thriller
# 45    46    14-Nov-14                          Kill Dil           N   Romance
# 46    47    15-Mar-13                Mere Dad Ki Maruti           N    Comedy
# 47    48    15-Mar-13                         Jolly LLB           N    Comedy
# 48    49     9-May-14                      Koyelaanchal          HS    Action
# 49    50     2-May-14              Kya Dilli Kya Lahore          HS    Drama
#
#     Budget  BoxOfficeCollection  YoutubeViews  YoutubeLikes  YoutubeDislikes
# ...

# %%
df.groupby(["Budget"]).mean()
# Out:
#               SlNo  BoxOfficeCollection  YoutubeViews  YoutubeLikes  \
# Budget
# 2        58.666667             2.970000  1.934300e+06   1590.000000
# 3        56.000000             1.750000  3.701060e+05    991.000000
# 4        67.750000             2.847500  2.251980e+05    124.250000
# 5        76.000000            11.295556  1.449165e+06   1771.333333
# 6       100.000000            27.150000  1.338527e+06   2960.500000
# 7        20.000000            11.950000  5.371870e+05   1303.333333
# 8        50.500000             5.390000  7.168645e+05    672.000000
# 9        60.000000            21.500000  1.208841e+06   1442.000000
# 10       58.333333            14.886667  1.073396e+06   1719.750000
# 11      100.333333            10.006667  1.398178e+06   2183.333333
# 12       61.333333            30.395556  4.067544e+06   6201.333333
# 13      146.000000            32.100000  5.592977e+06  15464.000000
# 14      126.000000             7.500000  4.045000e+04     33.000000
# ...

# %%
a = df.groupby(["Genre","ReleaseTime"])
a

# %%
df.groupby["Genre"]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
# ----> 1 df.groupby["Genre"]
#
# TypeError: 'method' object is not subscriptable
