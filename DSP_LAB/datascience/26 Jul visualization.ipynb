# %%
import numpy as np
import matplotlib.pyplot as plt

data = {'C':20,'C++':15,'Java':30,'Python':35}
Courses = list(data.keys())
Values = list(data.values())

fig = plt.figure(figsize = (10, 5))

plt.bar(Courses, Values, color ='maroon',width = 0.4)
plt.xlabel("Courses offered")
plt.ylabel("No of student enrolled")
plt.title("Student enrolled in different courses")
plt.show()

# %%
import matplotlib.pyplot as plt

country = ['US','India','Germany','UK','France']
GDP_per_Capital = [48000, 38000, 50000, 45000, 44000]

plt.bar(country, GDP_per_Capital)
plt.title('country Vs GDP_per_Capital')
plt.xlabel('country')
plt.ylabel('GDP_per_Capital')
plt.show()

# %%
import matplotlib.pyplot as plt

country = ['US','India','Germany','UK','France']
GDP_per_Capital = [48000, 38000, 50000, 45000, 44000]

plt.bar(country, GDP_per_Capital,color="r")
plt.title('country Vs GDP_per_Capital')
plt.xlabel('country')
plt.ylabel('GDP_per_Capital')
plt.show()

# %%
import matplotlib.pyplot as plt

numbers = [0.1, 0.5, 1, 1.5, 2, 4, 5.5, 6, 8, 9]
plt.hist(numbers, bins=5)

plt.xlabel("numbers")
plt.ylabel("frequency")
plt.show()

# %%
import matplotlib.pyplot as plt

numbers = [0.1, 0.5, 1, 1.5, 2, 4, 5.5, 6, 8, 9]
plt.hist(numbers, bins=5, color="r")

plt.xlabel("numbers")
plt.ylabel("frequency")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,50,15])
co = ["r","b","hotpink"]

plt.pie(y, colors=co, labels = ["DSP","CD","WT"])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

y = np.array([35,50,15])
co = ["r","b","hotpink"]

plt.legend(title="Subject")
plt.pie(y, colors=co, labels = ["DSP","CD","WT"])
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

# plot 1

x = np.array([0, 1, 2, 3])
y = np.array([0, 8, 1, 10])

plt.subplot(1, 2, 1)
plt.plot(x,y)

# plot 2

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(1, 2, 2)
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 0, 3, 3, 0, 3, 0, 0, 3])
y = np.array([0, 3, 3, 0, 0, 0, 3, 0, 3])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.array([0, 3, 3, 0, 0, 1.5, 3, 2.63, 0.37, 0.76, 2.25, 1.87, 1.14, 0, 0.50, 0.50, 1, 1, 1.5, 1.5, 2, 2, 2.5, 2.5])
y = np.array([3, 3, 0, 0, 3, 7.0, 3, 4.00, 4.00, 5.00, 5.00, 6.00, 6.00, 3, 3.00, 0.00, 0, 3, 3.0, 0.0, 0, 3, 3.0, 0.0])

plt.plot(x,y)
plt.show()
